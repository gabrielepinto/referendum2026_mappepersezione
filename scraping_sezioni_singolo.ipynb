# %%
from __future__ import annotations

import json
import re
import time
from pathlib import Path
from typing import Dict

import pandas as pd

from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options as FirefoxOptions
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

ROOT = Path.cwd()
LINKS_FILE = ROOT / "linkdownload_sezioni.txt"
DOWNLOAD_TURNOUT_DIR = ROOT / "downloads_csv"
DOWNLOAD_RESULTS_DIR = ROOT / "downloads_scrutini"
DOWNLOAD_TURNOUT_DIR.mkdir(exist_ok=True)
DOWNLOAD_RESULTS_DIR.mkdir(exist_ok=True)

DATE_TAG = "2026-03-22"

# %%
origin_folder = "C:\\Users\\gabri\\Documents\\GitHub\\referendum2026_mappepersezione\\scrutini_sezioni\\"

# %%
def parse_links_file(path: Path) -> Dict[str, str]:
    """Parsa il file testuale tipo:
    "roma":"https://...",
    "milano":"https://..."
    """
    text = path.read_text(encoding="utf-8")
    pairs = re.findall(r'"([^"]+)"\s*:\s*"([^"]+)"', text)
    if not pairs:
        raise ValueError(f"Nessun link trovato in {path}")
    return dict(pairs)


city_links = parse_links_file(LINKS_FILE)
city_links_scrutini = {city: url.replace("/votanti/", "/scrutini/") for city, url in city_links.items()}
pd.DataFrame(
    [
        {"city": city, "turnout_url": url, "results_url": city_links_scrutini[city]}
        for city, url in city_links.items()
    ]
)
# Out:
#              city                                        turnout_url  \
# 0            roma  https://elezioni.interno.gov.it/risultati/2026...
# 1          milano  https://elezioni.interno.gov.it/risultati/2026...
# 2          napoli  https://elezioni.interno.gov.it/risultati/2026...
# 3         bologna  https://elezioni.interno.gov.it/risultati/2026...
# 4          torino  https://elezioni.interno.gov.it/risultati/2026...
# 5          genova  https://elezioni.interno.gov.it/risultati/2026...
# 6         firenze  https://elezioni.interno.gov.it/risultati/2026...
# 7         palermo  https://elezioni.interno.gov.it/risultati/2026...
# 8  reggiocalabria  https://elezioni.interno.gov.it/risultati/2026...
# 9         taranto  https://elezioni.interno.gov.it/risultati/2026...
#
#                                          results_url
# 0  https://elezioni.interno.gov.it/risultati/2026...
# 1  https://elezioni.interno.gov.it/risultati/2026...
# 2  https://elezioni.interno.gov.it/risultati/2026...
# 3  https://elezioni.interno.gov.it/risultati/2026...
# 4  https://elezioni.interno.gov.it/risultati/2026...
# 5  https://elezioni.interno.gov.it/risultati/2026...
# 6  https://elezioni.interno.gov.it/risultati/2026...
# 7  https://elezioni.interno.gov.it/risultati/2026...
# 8  https://elezioni.interno.gov.it/risultati/2026...
# 9  https://elezioni.interno.gov.it/risultati/2026...

# %%
import re
import pandas as pd

def parse_dati(text):
    def extract(pattern, text, cast=str, transform=None, default=None):
        m = re.search(pattern, text, re.MULTILINE)
        if not m:
            return default
        value = m.group(1)
        if transform:
            value = transform(value)
        if cast:
            value = cast(value)
        return value

    dati = {
        "elettori": extract(
            r"Elettori:\s*([\d\.]+)",
            text,
            cast=int,
            transform=lambda x: x.replace(".", ""),
            default=None
        ),
        "votanti": extract(
            r"Votanti:\s*(\d+)",
            text,
            cast=int,
            default=None
        ),
        "affluenza": extract(
            r"Votanti:\s*\d+\s*\(([\d,]+)%\)",
            text,
            cast=float,
            transform=lambda x: x.replace(",", "."),
            default=None
        ),
        "schede_nulle": extract(
            r"Schede nulle:\s*(\d+)",
            text,
            cast=int,
            default=None
        ),
        "schede_bianche": extract(
            r"Schede bianche:\s*(\d+)",
            text,
            cast=int,
            default=None
        ),
        "schede_contestate": extract(
            r"Schede contestate:\s*(\d+)",
            text,
            cast=int,
            default=None
        ),
        "aggiornamento": extract(
            r"Aggiornamento:\s*(.*)",
            text,
            cast=str,
            default=None
        ),
    }

    return dati

# %%
def build_firefox_driver_new( headless: bool = True) -> webdriver.Firefox:
    options = FirefoxOptions()
    if headless:
        options.add_argument("-headless")

    driver = webdriver.Firefox(options=options)
    driver.set_window_size(1600, 2200)
    try:
        driver.maximize_window()
    except Exception:
        pass
    return driver

# %%
import tqdm

# %%
driver = build_firefox_driver_new(headless=False)

# %% [markdown]
# ## scraper sezioni

# %%
for city,base_scrut in city_links_scrutini.items():
    if city in ["roma"]:
        url_csv= origin_folder+f"{city}.csv"
        try:
            base_df = pd.read_csv(url_csv)
            base_df = base_df.loc[base_df["aggiornamento"].notna()]
            sezioni_fatte = base_df["sezione"].unique()
        except:
            base_df = pd.DataFrame()
            sezioni_fatte = []
        base_scrut = city_links_scrutini[city]
        ## vai all'homepage
        driver.get(base_scrut)
        time.sleep(5)
        nsezionstring = driver.find_element(By.CSS_SELECTOR, ".sezioni_perv")
        try:
            start_sezione = base_df["sezione"].max()
        except:
            start_sezione = 1
        print(f'We start at: {start_sezione}') 
        n_sezioni=int(nsezionstring.text.split("su ")[-1].replace(".",""))
        print(f'We start at: {n_sezioni}')
        risultati = []
        for sezione in range(start_sezione,n_sezioni+1):

            if sezione not in sezioni_fatte:
                sezione_url = str(sezione).zfill(4)
                sezione_url = base_scrut + sezione_url
                ## visita link sezione
                driver.get(sezione_url)
                time.sleep(1.5)
                ## prendi i risultati
                try:
                    element = driver.find_element(By.CSS_SELECTOR, ".riepilogo_basso.bg-ques-01")
                    element_voti = driver.find_elements(By.CSS_SELECTOR, "td.text-center.sino_vot")
                    si = int(element_voti[0].text)
                    no = int(element_voti[1].text)
                except:
                    print("aspettando")
                    time.sleep(3)
                    try:
                        element = driver.find_element(By.CSS_SELECTOR, ".riepilogo_basso.bg-ques-01")
                        element_voti = driver.find_elements(By.CSS_SELECTOR, "td.text-center.sino_vot")
                        si = int(element_voti[0].text)
                        no = int(element_voti[1].text)
                    except:
                        print("andando alla successiva")
                        next

                try:
                    risultato = parse_dati(element.text)
                    risultato["sezione"]=sezione
                    risultato["si"]=si
                    risultato["no"] =no
                    print(risultato)
                    risultati.append(risultato)
                    
                except:
                    next
            else:
                print("sezione fatta")
                pass
            if sezione%50==0:
                print(f'{city}{sezione}')
                cc = pd.DataFrame(risultati)
                base_df = pd.concat([base_df,cc])
                base_df.drop_duplicates(inplace=True)
                base_df.to_csv(url_csv,index=None)
    else:
        pass
# Out:
# We start at: 550
# We start at: 2599
# sezione fatta
# roma550
# {'elettori': 548, 'votanti': 308, 'affluenza': 56.2, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 -
 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 629}
# {'elettori': 936, 'votanti': 500, 'affluenza': 53.42, 'schede_nulle': 6, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:14', 'sezione': 630}
# {'elettori': 863, 'votanti': 510, 'affluenza': 59.1, 'schede_nulle': 1, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:17', 'sezione': 631}
# {'elettori': 468, 'votanti': 265, 'affluenza': 56.62, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 632}
# {'elettori': 631, 'votanti': 378, 'affluenza': 59.9, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:28', 'sezione': 633}
# {'elettori': 619, 'votanti': 390, 'affluenza': 63.0, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 634}
# {'elettori': 848, 'votanti': 534, 'affluenza': 62.97, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:14', 'sezione': 635}
# {'elettori': 677, 'votanti': 455, 'affluenza': 67.21, 'schede_nulle': 2, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:14', 'sezione': 636}
# {'elettori': 583, 'votanti': 405, 'affluenza': 69.47, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 637}
# {'elettori': 621, 'votanti': 446, 'affluenza': 71.82, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 638}
# {'elettori': 565, 'votanti': 398, 'affluenza': 70.44, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:14', 'sezione': 639}
# aspettando
# andando alla successiva
# {'elettori': 712, 'votanti': 399, 'affluenza': 56.04, 'schede_nulle': 1, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 641}
# {'elettori': 597, 'votanti': 418, 'affluenza': 70.02, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:28', 'sezione': 642}
# {'elettori': 619, 'votanti': 386, 'affluenza': 62.36, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:28', 'sezione': 643}
# {'elettori': 722, 'votanti': 542, 'affluenza': 75.07, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:30', 'sezione': 644}
# {'elettori': 1200, 'votanti': 850, 'affluenza': 70.83, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 645}
# {'elettori': 877, 'votanti': 562, 'affluenza': 64.08, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 646}
# {'elettori': None, 'votanti': None, 'affluenza': None, 'schede_nulle': None, 'schede_bianche': None, 'schede_contestate': None, 'aggiornamento': None, 'sezione': 647}
# {'elettori': 873, 'votanti': 621, 'affluenza': 71.13, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 648}
# aspettando
# {'elettori': 797, 'votanti': 576, 'affluenza': 72.27, 'schede_nulle': 3, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 649}
# {'elettori': 667, 'votanti': 485, 'affluenza': 72.71, 'schede_nulle': 2, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 650}
# roma650
# {'elettori': 844, 'votanti': 656, 'affluenza': 77.73, 'schede_nulle': 3, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:17', 'sezione': 651}
# {'elettori': 907, 'votanti': 657, 'affluenza': 72.44, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:26', 'sezione': 652}
# {'elettori': 682, 'votanti': 509, 'affluenza': 74.63, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:17', 'sezione': 653}
# {'elettori': 718, 'votanti': 543, 'affluenza': 75.63, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:17', 'sezione': 654}
# {'elettori': 701, 'votanti': 322, 'affluenza': 45.93, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 655}
# {'elettori': 767, 'votanti': 353, 'affluenza': 46.02, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 656}
# {'elettori': 1011, 'votanti': 555, 'affluenza': 54.9, 'schede_nulle': 4, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:32', 'sezione': 657}
# {'elettori': 578, 'votanti': 267, 'affluenza': 46.19, 'schede_nulle': 0, 'schede_bianche': 3, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 658}
# {'elettori': 602, 'votanti': 322, 'affluenza': 53.49, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:20', 'sezione': 659}
# {'elettori': 570, 'votanti': 244, 'affluenza': 42.81, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 660}
# {'elettori': 855, 'votanti': 455, 'affluenza': 53.22, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:40', 'sezione': 661}
# {'elettori': 1207, 'votanti': 676, 'affluenza': 56.01, 'schede_nulle': 1, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:32', 'sezione': 662}
# {'elettori': 778, 'votanti': 460, 'affluenza': 59.13, 'schede_nulle': 4, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:20', 'sezione': 663}
# {'elettori': 751, 'votanti': 443, 'affluenza': 58.99, 'schede_nulle': 4, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 664}
# {'elettori': 1023, 'votanti': 632, 'affluenza': 61.78, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:40', 'sezione': 665}
# {'elettori': 884, 'votanti': 536, 'affluenza': 60.63, 'schede_nulle': 5, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:40', 'sezione': 666}
# {'elettori': 1088, 'votanti': 670, 'affluenza': 61.58, 'schede_nulle': 3, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 667}
# {'elettori': None, 'votanti': None, 'affluenza': None, 'schede_nulle': None, 'schede_bianche': None, 'schede_contestate': None, 'aggiornamento': None, 'sezione': 668}
# {'elettori': 971, 'votanti': 588, 'affluenza': 60.56, 'schede_nulle': 1, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 18:00', 'sezione': 669}
# {'elettori': 1123, 'votanti': 642, 'affluenza': 57.17, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:17', 'sezione': 670}
# {'elettori': 822, 'votanti': 496, 'affluenza': 60.34, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 671}
# {'elettori': 981, 'votanti': 548, 'affluenza': 55.86, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:20', 'sezione': 672}
# {'elettori': 859, 'votanti': 543, 'affluenza': 63.21, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:30', 'sezione': 673}
# {'elettori': 744, 'votanti': 398, 'affluenza': 53.49, 'schede_nulle': 4, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 674}
# {'elettori': 885, 'votanti': 479, 'affluenza': 54.12, 'schede_nulle': 3, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:28', 'sezione': 675}
# {'elettori': 824, 'votanti': 454, 'affluenza': 55.1, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:20', 'sezione': 676}
# {'elettori': 357, 'votanti': 158, 'affluenza': 44.26, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 677}
# {'elettori': 887, 'votanti': 480, 'affluenza': 54.11, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:28', 'sezione': 678}
# {'elettori': 1008, 'votanti': 511, 'affluenza': 50.69, 'schede_nulle': 3, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 679}
# {'elettori': 938, 'votanti': 474, 'affluenza': 50.53, 'schede_nulle': 3, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:28', 'sezione': 680}
# {'elettori': 1017, 'votanti': 507, 'affluenza': 49.85, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 681}
# {'elettori': 1087, 'votanti': 533, 'affluenza': 49.03, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 682}
# {'elettori': 1122, 'votanti': 549, 'affluenza': 48.93, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:29', 'sezione': 683}
# {'elettori': 949, 'votanti': 310, 'affluenza': 32.67, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 684}
# {'elettori': 1024, 'votanti': 477, 'affluenza': 46.58, 'schede_nulle': 4, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 685}
# aspettando
# andando alla successiva
# {'elettori': 1128, 'votanti': 545, 'affluenza': 48.32, 'schede_nulle': 3, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:06', 'sezione': 687}
# {'elettori': 1115, 'votanti': 644, 'affluenza': 57.76, 'schede_nulle': 3, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 688}
# {'elettori': 1185, 'votanti': 623, 'affluenza': 52.57, 'schede_nulle': 3, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:59', 'sezione': 689}
# {'elettori': 988, 'votanti': 483, 'affluenza': 48.89, 'schede_nulle': 2, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 690}
# {'elettori': 1238, 'votanti': 568, 'affluenza': 45.88, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:26', 'sezione': 691}
# {'elettori': 1167, 'votanti': 557, 'affluenza': 47.73, 'schede_nulle': 4, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:26', 'sezione': 692}
# {'elettori': 1042, 'votanti': 481, 'affluenza': 46.16, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 693}
# {'elettori': 1010, 'votanti': 491, 'affluenza': 48.61, 'schede_nulle': 3, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 694}
# {'elettori': 503, 'votanti': 224, 'affluenza': 44.53, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 695}
# {'elettori': 509, 'votanti': 284, 'affluenza': 55.8, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 696}
# {'elettori': 771, 'votanti': 471, 'affluenza': 61.09, 'schede_nulle': 2, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:26', 'sezione': 697}
# {'elettori': 814, 'votanti': 533, 'affluenza': 65.48, 'schede_nulle': 3, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 698}
# {'elettori': 826, 'votanti': 456, 'affluenza': 55.21, 'schede_nulle': 3, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 699}
# {'elettori': 693, 'votanti': 391, 'affluenza': 56.42, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:29', 'sezione': 700}
# roma700
# {'elettori': 730, 'votanti': 412, 'affluenza': 56.44, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:59', 'sezione': 701}
# {'elettori': 659, 'votanti': 371, 'affluenza': 56.3, 'schede_nulle': 3, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:07', 'sezione': 702}
# {'elettori': 522, 'votanti': 259, 'affluenza': 49.62, 'schede_nulle': 5, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:29', 'sezione': 703}
# {'elettori': 674, 'votanti': 292, 'affluenza': 43.32, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16
 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 744}
# {'elettori': 769, 'votanti': 293, 'affluenza': 38.1, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 745}
# {'elettori': 420, 'votanti': 175, 'affluenza': 41.67, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 746}
# {'elettori': 528, 'votanti': 164, 'affluenza': 31.06, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 747}
# {'elettori': 482, 'votanti': 157, 'affluenza': 32.57, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 17:06', 'sezione': 748}
# {'elettori': 789, 'votanti': 387, 'affluenza': 49.05, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:14', 'sezione': 749}
# {'elettori': 536, 'votanti': 273, 'affluenza': 50.93, 'schede_nulle': 1, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:14', 'sezione': 750}
# roma750
# {'elettori': 630, 'votanti': 217, 'affluenza': 34.44, 'schede_nulle': 3, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:14', 'sezione': 751}
# {'elettori': 577, 'votanti': 230, 'affluenza': 39.86, 'schede_nulle': 2, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:14', 'sezione': 752}
# {'elettori': 680, 'votanti': 377, 'affluenza': 55.44, 'schede_nulle': 0, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 753}
# {'elettori': 766, 'votanti': 472, 'affluenza': 61.62, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:32', 'sezione': 754}
# {'elettori': 822, 'votanti': 458, 'affluenza': 55.72, 'schede_nulle': 1, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 755}
# {'elettori': 756, 'votanti': 412, 'affluenza': 54.5, 'schede_nulle': 4, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 756}
# {'elettori': 768, 'votanti': 434, 'affluenza': 56.51, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 757}
# {'elettori': 933, 'votanti': 473, 'affluenza': 50.7, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 758}
# {'elettori': 1170, 'votanti': 692, 'affluenza': 59.15, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 759}
# {'elettori': None, 'votanti': None, 'affluenza': None, 'schede_nulle': None, 'schede_bianche': None, 'schede_contestate': None, 'aggiornamento': None, 'sezione': 760}
# {'elettori': 1149, 'votanti': 597, 'affluenza': 51.96, 'schede_nulle': 3, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:47', 'sezione': 761}
# {'elettori': 1113, 'votanti': 573, 'affluenza': 51.48, 'schede_nulle': 3, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 762}
# {'elettori': None, 'votanti': None, 'affluenza': None, 'schede_nulle': None, 'schede_bianche': None, 'schede_contestate': None, 'aggiornamento': None, 'sezione': 763}
# {'elettori': 1112, 'votanti': 558, 'affluenza': 50.18, 'schede_nulle': 5, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 764}
# aspettando
# {'elettori': 1222, 'votanti': 680, 'affluenza': 55.65, 'schede_nulle': 5, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 765}
# {'elettori': 1124, 'votanti': 632, 'affluenza': 56.23, 'schede_nulle': 2, 'schede_bianche': 0, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:08', 'sezione': 766}
# {'elettori': 812, 'votanti': 399, 'affluenza': 49.14, 'schede_nulle': 0, 'schede_bianche': 4, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:40', 'sezione': 767}
# {'elettori': 901, 'votanti': 492, 'affluenza': 54.61, 'schede_nulle': 2, 'schede_bianche': 2, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 768}
# {'elettori': None, 'votanti': None, 'affluenza': None, 'schede_nulle': None, 'schede_bianche': None, 'schede_contestate': None, 'aggiornamento': None, 'sezione': 769}
# {'elettori': 1180, 'votanti': 608, 'affluenza': 51.53, 'schede_nulle': 0, 'schede_bianche': 1, 'schede_contestate': 0, 'aggiornamento': '23/03/2026 - 16:09', 'sezione': 770}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 31
#      29 ## visita link sezione
#      30 driver.get(sezione_url)
# ---> 31 time.sleep(3)
#      32 ## prendi i risultati
#      33 try:
#
# KeyboardInterrupt:

# %%
element.text
# Out:
# 'Elettori: 821'

# %%
risultati = [risultato]

# %%
pd.DataFrame(risultati).to_csv()
# Out:
#    elettori  votanti  affluenza  schede_nulle  schede_bianche  \
# 0      1208      827      68.46             1               1
#
#    schede_contestate       aggiornamento  sezione
# 0                  0  23/03/2026 - 16:02        1

# %%
15%15
# Out:
# 0
